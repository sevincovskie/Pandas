# %%
import pandas as pd
titanic = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/titanic.csv')
houses = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/kc_house_data.csv')
netflix = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/netflix_titles.csv', sep = "|",index_col=0)
btc = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/coin_Bitcoin.csv')
countries = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/world-happiness-report-2021.csv',index_col='Country name')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_theme()
sns.scatterplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex', style='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex', style='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex', style='day')
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex', style='sex',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
flight = sns.load_dataset('flights')
flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=flight,x='year',y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flight[flight.year==1950]
# Out:
#     year month  passengers
# 12  1950   Jan         115
# 13  1950   Feb         126
# 14  1950   Mar         141
# 15  1950   Apr         135
# 16  1950   May         125
# 17  1950   Jun         149
# 18  1950   Jul         170
# 19  1950   Aug         170
# 20  1950   Sep         158
# 21  1950   Oct         133
# 22  1950   Nov         114
# 23  1950   Dec         140

# %%
sns.lineplot(data=flight,x='year',y='passengers',estimator=sum)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flight,x='year',y='passengers',estimator=max)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flight.groupby('year').passengers.mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
sns.lineplot(data=flight,x='year',y='passengers',hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
from ast import parse
trips = sns.load_dataset('taxis',parse_dates = ['pickup','dropoff'])
trips
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
trips['hour']=trips['pickup'].dt.hour

# %%
sns.lineplot(data=trips,x='hour',y='total',hue='payment')
# Out:
# <Axes: xlabel='hour', ylabel='total'>

# %%
sns.lineplot(data=trips,x='hour',y='total',hue='payment',style='color')
# Out:
# <Axes: xlabel='hour', ylabel='total'>

# %%
sns.lineplot(data=trips,x='hour',y='total',hue='payment',style='color',ci=None)
# Out:
# /tmp/ipython-input-591699332.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=trips,x='hour',y='total',hue='payment',style='color',ci=None)
# <Axes: xlabel='hour', ylabel='total'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',col='sex')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='smoker')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='smoker',col='sex')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='smoker',col='sex',row='time')

# %%
sns.relplot(data=trips, x='hour', y='total',kind='line',col='pickup_borough')

# %%
sns.relplot(data=trips, x='hour', y='total',kind='line',col='pickup_borough',hue='payment')

# %%
sns.relplot(data=trips,
            x='hour',
            y='total',
            kind='line',
            col='pickup_borough',
            hue='payment',
            row='dropoff_borough')

# %%
sns.lineplot(data=flight, x='year',y='passengers',hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
plt.figure(figsize=(8,5))
sns.lineplot(data=flight, x='year',y='passengers',hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
plt.figure(figsize=(3,5))
sns.lineplot(data=flight, x='year',y='passengers',hue='month')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='smoker',col='sex')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='smoker',col='sex',height=4,aspect=2.5)

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='smoker',col='sex',height=4,row='day')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='smoker',col='sex',height=4,aspect=1,row='day')

# %%
sns.histplot(data=tips,x='tip')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips,x='tip',hue='time')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips,x='tip',hue='smoker',multiple='stack')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips,x='tip',hue='smoker',multiple='dodge')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(data=penguins,x='body_mass_g',hue='species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins,x='body_mass_g',hue='species',bins=10)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins,x='body_mass_g',hue='species',binwidth=100)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins,x='body_mass_g',hue='species',bins=10,binwidth=100,multiple='stack')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins,x='body_mass_g',hue='species',bins=10,binwidth=100,multiple='stack',element='step')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins,x='body_mass_g',hue='species',bins=10,binwidth=100,multiple='stack',kde=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.kdeplot(data=penguins,x='body_mass_g',hue='species')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=penguins,x='body_mass_g',hue='species',bw_adjust=0.5)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.histplot(data=penguins,x='flipper_length_mm')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins,x='flipper_length_mm',y='flipper_length_mm')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='flipper_length_mm'>

# %%
sns.kdeplot(data=penguins,y='flipper_length_mm',x='body_mass_g')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>
